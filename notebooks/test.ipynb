# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ussd22 = pd.read_csv('../data/ussd22a.csv', encoding='latin-1')

# %%
ussd22
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 0                    AL                1          190
# 1                    AL                1            5
# 2                    AL                1           30
# 3                    AL                1           60
# 4                    AL                1           90
# ...                 ...              ...          ...
# 13148                WY               56         6240
# 13149                WY               56         5820
# 13150                WY               56         4830
# 13151                WY               56         6090
# 13152                PR               72           30
#
#                                       Name Estimated Total Population  \
# 0           Alabaster City School District                     34,391
# 1         Albertville City School District                     22,801
# 2      Alexander City City School District                     16,945
# ...

# %%
ussd22.head()
# Out:
#   State Postal Code  State FIPS Code  District ID  \
# 0                AL                1          190
# 1                AL                1            5
# 2                AL                1           30
# 3                AL                1           60
# 4                AL                1           90
#
#                                   Name Estimated Total Population  \
# 0       Alabaster City School District                     34,391
# 1     Albertville City School District                     22,801
# 2  Alexander City City School District                     16,945
# 3       Andalusia City School District                      8,855
# 4        Anniston City School District                     21,443
#
#   Estimated Population 5-17  \
# 0                     6,494
# 1                     4,669
# 2                     2,661
# 3                     1,474
# 4                     2,892
#
# ...

# %%
tn_df = ussd22[ussd22['State Postal Code'] == 'TN']

# %%
tn_df.head()
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
#
#                                       Name Estimated Total Population  \
# 10946           Alamo City School District                      4,092
# 10947           Alcoa City School District                     11,360
# 10948      Anderson County School District                     50,514
# 10949  Arlington Community School District                     28,344
# 10950                  Athens City Schools                     14,465
#
#       Estimated Population 5-17  \
# 10946                       400
# 10947                     1,861
# 10948                     7,074
# 10949                     4,562
# 10950                     1,491
#
# ...

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141 entries, 10946 to 11086
# Data columns (total 7 columns):
#  #   Column                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                 --------------  -----
#  0   State Postal Code                                                                                      141 non-null    object
#  1   State FIPS Code                                                                                        141 non-null    int64
#  2   District ID                                                                                            141 non-null    int64
#  3   Name                                                                                                   141 non-null    object
# ...

# %%
tn_df.dtypes
# Out:
# State Postal Code                                                                                        object
# State FIPS Code                                                                                           int64
# District ID                                                                                               int64
# Name                                                                                                     object
# Estimated Total Population                                                                               object
# Estimated Population 5-17                                                                                object
# Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder    object
# dtype: object

# %% [markdown]
# #tn_df['Estimated Total Population'] = pd.to_numeric(tn_df['Estimated Total Population'], errors='coerce')

# %%
tn_df.dtypes
# Out:
# State Postal Code                                                                                        object
# State FIPS Code                                                                                           int64
# District ID                                                                                               int64
# Name                                                                                                     object
# Estimated Total Population                                                                               object
# Estimated Population 5-17                                                                                object
# Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder    object
# dtype: object

# %% [markdown]
# tn_df['Estimated Population 5-17'] = pd.to_numeric(tn_df['Estimated Total Population'], errors='coerce')

# %% [markdown]
# tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'] = pd.to_numeric(tn_df['Estimated Total Population'], errors='coerce')

# %%
tn_df.dtypes
# Out:
# State Postal Code                                                                                        object
# State FIPS Code                                                                                           int64
# District ID                                                                                               int64
# Name                                                                                                     object
# Estimated Total Population                                                                               object
# Estimated Population 5-17                                                                                object
# Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder    object
# dtype: object

# %%
tn_df.head()
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
#
#                                       Name Estimated Total Population  \
# 10946           Alamo City School District                      4,092
# 10947           Alcoa City School District                     11,360
# 10948      Anderson County School District                     50,514
# 10949  Arlington Community School District                     28,344
# 10950                  Athens City Schools                     14,465
#
#       Estimated Population 5-17  \
# 10946                       400
# 10947                     1,861
# 10948                     7,074
# 10949                     4,562
# 10950                     1,491
#
# ...

# %%
tn_df.dtypes
# Out:
# State Postal Code                                                                                        object
# State FIPS Code                                                                                           int64
# District ID                                                                                               int64
# Name                                                                                                     object
# Estimated Total Population                                                                               object
# Estimated Population 5-17                                                                                object
# Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder    object
# dtype: object

# %%
tn_df['Estimated Total Population'] = tn_df['Estimated Total Population'].str.replace(',', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\483572754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['Estimated Total Population'] = tn_df['Estimated Total Population'].str.replace(',', '')

# %%
tn_df.head()
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
#
#                                       Name Estimated Total Population  \
# 10946           Alamo City School District                       4092
# 10947           Alcoa City School District                      11360
# 10948      Anderson County School District                      50514
# 10949  Arlington Community School District                      28344
# 10950                  Athens City Schools                      14465
#
#       Estimated Population 5-17  \
# 10946                       400
# 10947                     1,861
# 10948                     7,074
# 10949                     4,562
# 10950                     1,491
#
# ...

# %%
tn_df['Estimated Population 5-17'] = tn_df['Estimated Population 5-17'].str.replace(',', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\531072980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['Estimated Population 5-17'] = tn_df['Estimated Population 5-17'].str.replace(',', '')

# %%
tn_df.head()
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
#
#                                       Name Estimated Total Population  \
# 10946           Alamo City School District                       4092
# 10947           Alcoa City School District                      11360
# 10948      Anderson County School District                      50514
# 10949  Arlington Community School District                      28344
# 10950                  Athens City Schools                      14465
#
#       Estimated Population 5-17  \
# 10946                       400
# 10947                      1861
# 10948                      7074
# 10949                      4562
# 10950                      1491
#
# ...

# %%
tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'] = tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'].str.replace(',', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\4051022496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'] = tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'].str.replace(',', '')

# %%
tn_df
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
# ...                 ...              ...          ...
# 11082                TN               47         4470
# 11083                TN               47         4490
# 11084                TN               47         4500
# 11085                TN               47         4530
# 11086                TN               47         4550
#
#                                       Name Estimated Total Population  \
# 10946           Alamo City School District                       4092
# 10947           Alcoa City School District                      11360
# 10948      Anderson County School District                      50514
# ...

# %%
tn_df[['Estimated Total Population', 'Estimated Population 5-17', 'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder']] = tn_df[['Estimated Total Population', 'Estimated Population 5-17', 'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder']].astype(int)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\768141479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df[['Estimated Total Population', 'Estimated Population 5-17', 'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder']] = tn_df[['Estimated Total Population', 'Estimated Population 5-17', 'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder']].astype(int)

# %%
tn_df.dtypes
# Out:
# State Postal Code                                                                                        object
# State FIPS Code                                                                                           int64
# District ID                                                                                               int64
# Name                                                                                                     object
# Estimated Total Population                                                                                int32
# Estimated Population 5-17                                                                                 int32
# Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder     int32
# dtype: object

# %%
tn_df
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
# ...                 ...              ...          ...
# 11082                TN               47         4470
# 11083                TN               47         4490
# 11084                TN               47         4500
# 11085                TN               47         4530
# 11086                TN               47         4550
#
#                                       Name  Estimated Total Population  \
# 10946           Alamo City School District                        4092
# 10947           Alcoa City School District                       11360
# 10948      Anderson County School District                       50514
# ...

# %%
tn_df['Percentage of Population 5-17'] = (tn_df['Estimated Population 5-17'] / tn_df['Estimated Total Population']) * 100
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1577276061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['Percentage of Population 5-17'] = (tn_df['Estimated Population 5-17'] / tn_df['Estimated Total Population']) * 100

# %%
tn_df
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
# ...                 ...              ...          ...
# 11082                TN               47         4470
# 11083                TN               47         4490
# 11084                TN               47         4500
# 11085                TN               47         4530
# 11086                TN               47         4550
#
#                                       Name  Estimated Total Population  \
# 10946           Alamo City School District                        4092
# 10947           Alcoa City School District                       11360
# 10948      Anderson County School District                       50514
# ...

# %%
tn_df['Percentage of Population 5-17 in Poverty'] = (tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'] / tn_df['Estimated Population 5-17']) * 100
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3434305491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['Percentage of Population 5-17 in Poverty'] = (tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'] / tn_df['Estimated Population 5-17']) * 100

# %%
tn_df
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
# ...                 ...              ...          ...
# 11082                TN               47         4470
# 11083                TN               47         4490
# 11084                TN               47         4500
# 11085                TN               47         4530
# 11086                TN               47         4550
#
#                                       Name  Estimated Total Population  \
# 10946           Alamo City School District                        4092
# 10947           Alcoa City School District                       11360
# 10948      Anderson County School District                       50514
# ...

# %%
tn_df.rename(columns={'Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder': 'Number of children 5-17 in poverty'})
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10946                TN               47           30
# 10947                TN               47           60
# 10948                TN               47           90
# 10949                TN               47          152
# 10950                TN               47          120
# ...                 ...              ...          ...
# 11082                TN               47         4470
# 11083                TN               47         4490
# 11084                TN               47         4500
# 11085                TN               47         4530
# 11086                TN               47         4550
#
#                                       Name  Estimated Total Population  \
# 10946           Alamo City School District                        4092
# 10947           Alcoa City School District                       11360
# 10948      Anderson County School District                       50514
# ...

# %%
largest_poverty_district = tn_df.sort_values(by='Percentage of Population 5-17 in Poverty', ascending=False)

# %%
largest_poverty_district
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 11045                TN               47         3210
# 11018                TN               47         2280
# 10998                TN               47         1620
# 11048                TN               47         3300
# 11050                TN               47         3360
# ...                 ...              ...          ...
# 10986                TN               47           78
# 10972                TN               47          149
# 10949                TN               47          152
# 10989                TN               47          151
# 11085                TN               47         4530
#
#                                        Name  Estimated Total Population  \
# 11045          Newport City School District                        7036
# 11018           Lake County School District                        6507
# 10998        Hancock County School District                        6845
# ...

# %%
largest_5through17_percent_population = tn_df.sort_values(by='Percentage of Population 5-17', ascending=False)

# %%
largest_5through17_percent_population
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 10972                TN               47          149
# 10986                TN               47           78
# 10990                TN               47         1400
# 10989                TN               47          151
# 10966                TN               47         3030
# ...                 ...              ...          ...
# 10946                TN               47           30
# 10988                TN               47         1260
# 11044                TN               47         3150
# 10953                TN               47          210
# 10969                TN               47          720
#
#                                               Name  \
# 10972                 Collierville School District
# 10986                        Fort Campbell Schools
# 10990                Gibson County School District
# 10989         Germantown Municipal School District
# 10966  Clarksville-Montgomery County School System
# ...

# %%
largest_population = tn_df.sort_values(by='Estimated Total Population', ascending=False)

# %%
top_20_pop = largest_population.head(20)

# %%
top_20_pop
# Out:
#       State Postal Code  State FIPS Code  District ID  \
# 11064                TN               47          148
# 11038                TN               47         3180
# 11017                TN               47         2220
# 10997                TN               47         1590
# 11060                TN               47         3690
# 11085                TN               47         4530
# 10966                TN               47         3030
# 11069                TN               47         4020
# 11044                TN               47         3150
# 11086                TN               47         4550
# 11033                TN               47         2760
# 11012                TN               47         2580
# 11063                TN               47         3780
# 10956                TN               47          300
# 11054                TN               47         3480
# 11068                TN               47         3990
# ...

# %%
avg_pov_kids = tn_df['Percentage of Population 5-17 in Poverty'].mean()

# %%
avg_pov_kids
# Out:
# 19.114595040002623

# %%
kids_pov = tn_df['Estimated number of relevant children 5 to 17 years old in poverty who are related to the householder'].sum()

# %%
kids_pov
# Out:
# 184826

# %%
tn_df.to_csv('tn_df.csv', index=False)

# %%
district_profile2223 = pd.read_csv('../data/new-district-profile-2022-2023.csv', encoding='latin-1')

# %%
district_profile2223
# Out:
#     school_year  district_id  \
# 0       2022-23            0
# 1       2022-23           10
# 2       2022-23           11
# 3       2022-23           12
# 4       2022-23           20
# ..          ...          ...
# 144     2022-23          963
# 145     2022-23          964
# 146     2022-23          970
# 147     2022-23          985
# 148     2022-23          987
#
#                                          district_name   total  \
# 0                                   State of Tennessee  973983
# 1                                      Anderson County    6019
# 2                                              Clinton     933
# 3                                            Oak Ridge    4730
# 4                                       Bedford County    8827
# ..                                                 ...     ...
# 144                         Tennessee School for Blind     126
# 145                      Tennessee School for the Deaf     129
# ...

# %% [markdown]
# largest_number_of_students = district_profile2223.sort_values(by='total', ascending=False)

# %% [markdown]
# largest_number_of_students

# %%
district_profile2223.dtypes
# Out:
# school_year                           object
# district_id                            int64
# district_name                         object
# total                                 object
# african_american_pct                  object
# asian_pct                             object
# black_hispanic_native_american_pct    object
# economically_disadvantaged_pct        object
# female_pct                            object
# foster_pct                            object
# hawaiian_pacisld_pct                  object
# hispanic_pct                          object
# homeless_pct                          object
# limited_english_proficient_pct        object
# male_pct                              object
# migrant_pct                           object
# military_pct                          object
# multirace_pct                         object
# native_american_pct                   object
# students_with_disabilities_pct        object
# white_pct                             object
# ...

# %%
filtered_district = district_profile2223[district_profile2223['total'] != 'Fewer than 10 students']

# %%
filtered_district[['total']] = filtered_district[['total']].astype(int)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\4060154135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district[['total']] = filtered_district[['total']].astype(int)

# %%
filtered_district.dtypes
# Out:
# school_year                           object
# district_id                            int64
# district_name                         object
# total                                  int32
# african_american_pct                  object
# asian_pct                             object
# black_hispanic_native_american_pct    object
# economically_disadvantaged_pct        object
# female_pct                            object
# foster_pct                            object
# hawaiian_pacisld_pct                  object
# hispanic_pct                          object
# homeless_pct                          object
# limited_english_proficient_pct        object
# male_pct                              object
# migrant_pct                           object
# military_pct                          object
# multirace_pct                         object
# native_american_pct                   object
# students_with_disabilities_pct        object
# white_pct                             object
# ...

# %%
largest_number_of_students = filtered_district.sort_values(by='total', ascending=False)

# %%
largest_number_of_students
# Out:
#     school_year  district_id                       district_name   total  \
# 0       2022-23            0                  State of Tennessee  973983
# 114     2022-23          792       Memphis-Shelby County Schools  104944
# 35      2022-23          190      Metro Nashville Public Schools   77435
# 72      2022-23          470                         Knox County   58879
# 108     2022-23          750                   Rutherford County   50026
# ..          ...          ...                                 ...     ...
# 18      2022-23           95                       South Carroll     306
# 88      2022-23          581                        Richard City     170
# 145     2022-23          964       Tennessee School for the Deaf     129
# 144     2022-23          963          Tennessee School for Blind     126
# 142     2022-23          960  West Tennessee School for the Deaf      24
#
#     african_american_pct asian_pct black_hispanic_native_american_pct  \
# ...

# %%
row_location = filtered_district[filtered_district['economically_disadvantaged_pct'] == 'More than 99%']

# %%
row_location
# Out:
#     school_year  district_id  \
# 146     2022-23          970
#
#                                          district_name  total  \
# 146  Department Of Children's Services Education Di...   1159
#
#     african_american_pct     asian_pct black_hispanic_native_american_pct  \
# 146                   35  Less than 1%                                 39
#
#     economically_disadvantaged_pct female_pct     foster_pct  ...  \
# 146                  More than 99%         28  More than 99%  ...
#
#     hispanic_pct  homeless_pct limited_english_proficient_pct male_pct  \
# 146            3  Less than 1%                              2       72
#
#                 migrant_pct  military_pct multirace_pct native_american_pct  \
# 146  Fewer than 10 students  Less than 1%             7        Less than 1%
#
#     students_with_disabilities_pct white_pct
# 146                             45        61
#
# [1 rows x 21 columns]

# %%
filtered_district = filtered_district[filtered_district['economically_disadvantaged_pct'] != 'More than 99%']

# %%
filtered_district[['economically_disadvantaged_pct']] = filtered_district[['economically_disadvantaged_pct']].astype(int)

# %%
filtered_district.dtypes
# Out:
# school_year                           object
# district_id                            int64
# district_name                         object
# total                                  int32
# african_american_pct                  object
# asian_pct                             object
# black_hispanic_native_american_pct    object
# economically_disadvantaged_pct         int32
# female_pct                            object
# foster_pct                            object
# hawaiian_pacisld_pct                  object
# hispanic_pct                          object
# homeless_pct                          object
# limited_english_proficient_pct        object
# male_pct                              object
# migrant_pct                           object
# military_pct                          object
# multirace_pct                         object
# native_american_pct                   object
# students_with_disabilities_pct        object
# white_pct                             object
# ...

# %%
largest_number_econ_disandantage = filtered_district.sort_values(by='economically_disadvantaged_pct', ascending=False)

# %%
largest_number_econ_disandantage.head(30)
# Out:
#     school_year  district_id                               district_name  \
# 147     2022-23          985                 Achievement School District
# 73      2022-23          480                                 Lake County
# 88      2022-23          581                                Richard City
# 44      2022-23          271                       Humboldt City Schools
# 114     2022-23          792               Memphis-Shelby County Schools
# 148     2022-23          987  Tennessee Public Charter School Commission
# 26      2022-23          150                                Cocke County
# 57      2022-23          350                     Hardeman County Schools
# 56      2022-23          340                              Hancock County
# 86      2022-23          570                              Madison County
# 40      2022-23          231                                   Dyersburg
# 34      2022-23          180                           Cumberland County
# ...

# %%
newport = filtered_district[filtered_district['district_name'] == 'Newport']

# %%
newport
# Out:
#    school_year  district_id district_name  total african_american_pct  \
# 27     2022-23          151       Newport    657                    7
#
#    asian_pct black_hispanic_native_american_pct  \
# 27         5                                 12
#
#     economically_disadvantaged_pct female_pct    foster_pct  ... hispanic_pct  \
# 27                              29         51  Less than 1%  ...            4
#
#               homeless_pct limited_english_proficient_pct male_pct  \
# 27  Fewer than 10 students                              3       49
#
#      migrant_pct  military_pct multirace_pct native_american_pct  \
# 27  Less than 1%  Less than 1%            10                   1
#
#    students_with_disabilities_pct white_pct
# 27                             10        82
#
# [1 rows x 21 columns]

# %%
filtered_district['zip code'] = ['0', '37769', '37716', '37830', '37160', '38320', '37367', '37737', '37701', '37803', '37311', '37312', '37757', '37190', '38317', '38344', '38201', '38324', '38220', '37658', '37643', '37015', '38340', '37879', '38551', '37727', '37821', '37382', '37355', '37388', '38050', '38001', '38006', '38555', '37204', '38329', '37166', '37055', '38059', '38024', '38068', '38556', '37398', '38343', '38358', '38382', '38316', '38338', '38478', '37861', '37818', '37743', '37301', '37813', '37421', '37869', '38008', '38372', '37642', '37857', '38012', '38368', '38351', '38251', '38242', '37033', '37061', '37185', '38562', '37725', '37683', '37902', '38079', '38063', '38464', '38462', '37348', '37334', '37774', '37771', '37826', '37303', '37331', '38375', '37083', '38305', '37347', '37380', '37091', '38401', '37322', '37354', '37874', '37040', '37352', '37887', '38260', '38261', '38570', '37096', '38549', '37307', '38506', '37332', '37321', '37763', '37172', '37127', '37128', '37756', '37841', '37327', '37862', '38112', '38028', '38134', '38017', '38138', '38002', '38053', '37030', '37058', '37617', '37620', '37660', '37066', '38019', '37074', '37650', '37807', '38585', '37110', '37659', '37605', '38485', '38225', '38583', '37027', '37064', '37122', '37087','38301', '38556', '37214', '37920', '38104', '37243']

# %%
filtered_district.head(120)
# Out:
#     school_year  district_id                 district_name   total  \
# 0       2022-23            0            State of Tennessee  973983
# 1       2022-23           10               Anderson County    6019
# 2       2022-23           11                       Clinton     933
# 3       2022-23           12                     Oak Ridge    4730
# 4       2022-23           20                Bedford County    8827
# ..          ...          ...                           ...     ...
# 116     2022-23          794                      Bartlett    8785
# 117     2022-23          795                  Collierville    9105
# 118     2022-23          796                    Germantown    5899
# 119     2022-23          797                      Lakeland    2080
# 120     2022-23          798  Millington Municipal Schools    2475
#
#     african_american_pct     asian_pct black_hispanic_native_american_pct  \
# 0                     24             3                                 38
# ...

# %%
filtered_district.to_csv('filtered_district.csv', index=False)

# %%
district_assessment = pd.read_csv('../data/district_assessment_file_suppressed_2023a.csv', encoding='latin-1')

# %%
district_assessment
# Out:
#         year  system                  system_name test     subject  \
# 0       2023     950                Wilson County  EOC   Algebra I
# 1       2023     950                Wilson County  EOC   Algebra I
# 2       2023     950                Wilson County  EOC   Algebra I
# 3       2023     950                Wilson County  EOC   Algebra I
# 4       2023     950                Wilson County  EOC   Algebra I
# ...      ...     ...                          ...  ...         ...
# 180230  2023     985  Achievement School District  EOC  US History
# 180231  2023     985  Achievement School District  EOC  US History
# 180232  2023     985  Achievement School District  EOC  US History
# 180233  2023     985  Achievement School District  EOC  US History
# 180234  2023     985  Achievement School District  EOC  US History
#
#              grade                          student_group participation_rate  \
# 0               10                           All Students                100
# ...

# %%
all_grades = district_assessment[district_assessment['grade'] == 'All Grades']

# %%
all_grades
# Out:
#         year  system                  system_name test     subject  \
# 86      2023     950                Wilson County  EOC   Algebra I
# 87      2023     950                Wilson County  EOC   Algebra I
# 88      2023     950                Wilson County  EOC   Algebra I
# 89      2023     950                Wilson County  EOC   Algebra I
# 90      2023     950                Wilson County  EOC   Algebra I
# ...      ...     ...                          ...  ...         ...
# 180230  2023     985  Achievement School District  EOC  US History
# 180231  2023     985  Achievement School District  EOC  US History
# 180232  2023     985  Achievement School District  EOC  US History
# 180233  2023     985  Achievement School District  EOC  US History
# 180234  2023     985  Achievement School District  EOC  US History
#
#              grade                          student_group participation_rate  \
# 86      All Grades                           All Students                 99
# ...

# %%
unique_stgroup = district_assessment['student_group'].unique()

# %%
unique_stgroup
# Out:
# array(['All Students', 'Asian', 'Black or African American',
#        'Black/Hispanic/Native American', 'Economically Disadvantaged',
#        'English Learners', 'English Learners with Transitional 1-4',
#        'Female', 'Foster', 'Hispanic', 'Homeless', 'Male',
#        'Non-Black/Hispanic/Native American',
#        'Non-Economically Disadvantaged',
#        'Non-English Learners/Transitional 1-4',
#        'Non-Students with Disabilities',
#        'Students with Active Duty Military Parents',
#        'Students with Disabilities', 'Super Subgroup', 'White',
#        'English Learner Transitional 1-4', 'Gifted',
#        'Native Hawaiian or Other Pacific Islander',
#        'American Indian or Alaska Native', 'Migrant'], dtype=object)

# %%
filtered_assessment = district_assessment[district_assessment['participation_rate'] != '*']

# %%
filtered_assessment.dtypes
# Out:
# year                          int64
# system                        int64
# system_name                  object
# test                         object
# subject                      object
# grade                        object
# student_group                object
# participation_rate           object
# enrolled                      int64
# tested                        int64
# valid_tests                   int64
# n_below                      object
# n_approaching                object
# n_met_expectations           object
# n_exceeded_expectations      object
# pct_below                    object
# pct_approaching              object
# pct_met_expectations         object
# pct_exceeded_expectations    object
# pct_met_exceeded             object
# dtype: object

# %%
filtered_assessment['pct_below'] = filtered_assessment['pct_below'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3123433448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_below'] = filtered_assessment['pct_below'].str.replace('**', '')

# %%
filtered_assessment['pct_below'] = filtered_assessment['pct_below'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3581556965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_below'] = filtered_assessment['pct_below'].str.replace('*', '')

# %%
filtered_assessment.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1657455749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment.replace("", np.nan, inplace=True)

# %%
filtered_assessment[['pct_below']] = filtered_assessment[['pct_below']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\484993017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment[['pct_below']] = filtered_assessment[['pct_below']].astype(float)

# %%
filtered_assessment.dtypes
# Out:
# year                           int64
# system                         int64
# system_name                   object
# test                          object
# subject                       object
# grade                         object
# student_group                 object
# participation_rate            object
# enrolled                       int64
# tested                         int64
# valid_tests                    int64
# n_below                       object
# n_approaching                 object
# n_met_expectations            object
# n_exceeded_expectations       object
# pct_below                    float64
# pct_approaching               object
# pct_met_expectations          object
# pct_exceeded_expectations     object
# pct_met_exceeded              object
# dtype: object

# %%
largest_pct_below = filtered_assessment.sort_values(by='pct_below', ascending=False)

# %%
largest_pct_below
# Out:
#         year  system                  system_name test            subject  \
# 56327   2023     630            Montgomery County  EOC          Algebra I
# 143409  2023     190              Davidson County  EOC  Integrated Math I
# 143395  2023     190              Davidson County  EOC  Integrated Math I
# 170033  2023      20               Bedford County  EOC          Algebra I
# 175488  2023      10              Anderson County  EOC          Algebra I
# ...      ...     ...                          ...  ...                ...
# 180229  2023     985  Achievement School District  EOC         US History
# 180230  2023     985  Achievement School District  EOC         US History
# 180231  2023     985  Achievement School District  EOC         US History
# 180232  2023     985  Achievement School District  EOC         US History
# 180233  2023     985  Achievement School District  EOC         US History
#
#              grade                           student_group participation_rate  \
# ...

# %%
smallest_pct_below = filtered_assessment.sort_values(by='pct_below', ascending=True)

# %%
smallest_pct_below
# Out:
#         year  system                  system_name     test         subject  \
# 126799  2023     796                   Germantown  TNReady         Science
# 47782   2023     401                        Paris  TNReady  Social Studies
# 126084  2023     796                   Germantown  TNReady             ELA
# 126766  2023     796                   Germantown  TNReady         Science
# 119516  2023     301                  Greeneville      EOC       English I
# ...      ...     ...                          ...      ...             ...
# 180229  2023     985  Achievement School District      EOC      US History
# 180230  2023     985  Achievement School District      EOC      US History
# 180231  2023     985  Achievement School District      EOC      US History
# 180232  2023     985  Achievement School District      EOC      US History
# 180233  2023     985  Achievement School District      EOC      US History
#
# ...

# %%
filtered_assessment['pct_exceeded_expectations'] = filtered_assessment['pct_exceeded_expectations'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\2301993251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_exceeded_expectations'] = filtered_assessment['pct_exceeded_expectations'].str.replace('**', '')

# %%
filtered_assessment['pct_exceeded_expectations'] = filtered_assessment['pct_exceeded_expectations'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1087380817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_exceeded_expectations'] = filtered_assessment['pct_exceeded_expectations'].str.replace('*', '')

# %%
filtered_assessment.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1657455749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment.replace("", np.nan, inplace=True)

# %%
filtered_assessment[['pct_exceeded_expectations']] = filtered_assessment[['pct_exceeded_expectations']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\4113858117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment[['pct_exceeded_expectations']] = filtered_assessment[['pct_exceeded_expectations']].astype(float)

# %%
largest_pct_exceed = filtered_assessment.sort_values(by='pct_exceeded_expectations', ascending=False)

# %%
largest_pct_exceed
# Out:
#         year  system                  system_name test              subject  \
# 35356   2023     750            Rutherford County  EOC    Integrated Math I
# 119597  2023     301                  Greeneville  EOC             Geometry
# 119607  2023     301                  Greeneville  EOC             Geometry
# 119608  2023     301                  Greeneville  EOC             Geometry
# 143643  2023     190              Davidson County  EOC  Integrated Math III
# ...      ...     ...                          ...  ...                  ...
# 180229  2023     985  Achievement School District  EOC           US History
# 180230  2023     985  Achievement School District  EOC           US History
# 180231  2023     985  Achievement School District  EOC           US History
# 180232  2023     985  Achievement School District  EOC           US History
# 180233  2023     985  Achievement School District  EOC           US History
#
# ...

# %%
sg_count = filtered_assessment['student_group'].value_counts()

# %%
sg_count
# Out:
# student_group
# All Students                                  7146
# Non-English Learners/Transitional 1-4         7073
# Super Subgroup                                6813
# Non-Economically Disadvantaged                6594
# Non-Black/Hispanic/Native American            6582
# Male                                          6546
# White                                         6525
# Female                                        6119
# Non-Students with Disabilities                5980
# Economically Disadvantaged                    5830
# Students with Disabilities                    5620
# Black/Hispanic/Native American                5089
# Black or African American                     4065
# Hispanic                                      3726
# English Learners with Transitional 1-4        2078
# English Learners                              1474
# English Learner Transitional 1-4              1256
# Homeless                                      1161
# ...

# %%
filtered_assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93023 entries, 0 to 180233
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       93023 non-null  int64
#  1   system                     93023 non-null  int64
#  2   system_name                93023 non-null  object
#  3   test                       93023 non-null  object
#  4   subject                    93023 non-null  object
#  5   grade                      93023 non-null  object
#  6   student_group              93023 non-null  object
#  7   participation_rate         93023 non-null  object
#  8   enrolled                   93023 non-null  int64
#  9   tested                     93023 non-null  int64
#  10  valid_tests                93023 non-null  int64
#  11  n_below                    93023 non-null  object
#  12  n_approaching              93023 non-null  object
# ...

# %%
filtered_assessment['pct_met_exceeded'] = filtered_assessment['pct_met_exceeded'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3339066998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_met_exceeded'] = filtered_assessment['pct_met_exceeded'].str.replace('**', '')

# %%
filtered_assessment['pct_met_exceeded'] = filtered_assessment['pct_met_exceeded'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3881600083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_met_exceeded'] = filtered_assessment['pct_met_exceeded'].str.replace('*', '')

# %%
filtered_assessment.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1657455749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment.replace("", np.nan, inplace=True)

# %%
filtered_assessment[['pct_met_exceeded']] = filtered_assessment[['pct_met_exceeded']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\2521711315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment[['pct_met_exceeded']] = filtered_assessment[['pct_met_exceeded']].astype(float)

# %%
filtered_assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93023 entries, 0 to 180233
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       93023 non-null  int64
#  1   system                     93023 non-null  int64
#  2   system_name                93023 non-null  object
#  3   test                       93023 non-null  object
#  4   subject                    93023 non-null  object
#  5   grade                      93023 non-null  object
#  6   student_group              93023 non-null  object
#  7   participation_rate         93023 non-null  object
#  8   enrolled                   93023 non-null  int64
#  9   tested                     93023 non-null  int64
#  10  valid_tests                93023 non-null  int64
#  11  n_below                    93023 non-null  object
#  12  n_approaching              93023 non-null  object
# ...

# %%
sg_me = filtered_assessment.groupby('student_group')['pct_met_exceeded'].mean().sort_values(ascending=False)

# %%
sg_me
# Out:
# student_group
# Gifted                                        91.512977
# Asian                                         65.925804
# Native Hawaiian or Other Pacific Islander     48.013397
# American Indian or Alaska Native              46.820181
# Non-Economically Disadvantaged                42.666179
# Non-Black/Hispanic/Native American            42.265537
# White                                         41.976385
# Non-Students with Disabilities                41.177150
# Non-English Learners/Transitional 1-4         39.421423
# Female                                        38.913759
# All Students                                  38.819194
# Male                                          38.288455
# English Learner Transitional 1-4              38.221923
# Hispanic                                      32.212331
# Black/Hispanic/Native American                29.760260
# Super Subgroup                                28.986072
# ...

# %%
sg_below = filtered_assessment.groupby('student_group')['pct_below'].mean().sort_values(ascending=False)

# %%
sg_below
# Out:
# student_group
# Students with Disabilities                    43.856874
# English Learners                              38.901826
# Homeless                                      34.199194
# English Learners with Transitional 1-4        33.427004
# Students with Active Duty Military Parents    32.676812
# Foster                                        32.676812
# Super Subgroup                                31.490484
# Economically Disadvantaged                    30.818427
# Black or African American                     29.027640
# Black/Hispanic/Native American                28.624109
# Hispanic                                      27.298267
# Male                                          25.257436
# All Students                                  23.832983
# Non-English Learners/Transitional 1-4         23.227920
# Female                                        21.506942
# White                                         21.287549
# ...

# %%
system_me = filtered_assessment.groupby('system_name')['pct_met_exceeded'].mean().sort_values(ascending=False)

# %%
system_me.head(20)
# Out:
# system_name
# Lakeland             59.532086
# Arlington            57.126222
# Williamson County    55.773851
# Maryville            55.223207
# Germantown           55.117582
# Franklin SSD         52.234263
# Collierville         52.143815
# Newport              51.767018
# Johnson City         49.483114
# Lexington            49.343413
# Gibson Co Sp Dist    48.324168
# Alamo                47.306787
# Paris                47.221410
# Oak Ridge            47.177344
# Clinton              47.085514
# Trousdale County     46.879727
# Bells                46.710526
# Bartlett             46.673220
# Wilson County        45.460450
# Bradford             45.376733
# Name: pct_met_exceeded, dtype: float64

# %%
system_below = filtered_assessment.groupby('system_name')['pct_below'].mean().sort_values(ascending=False)

# %%
system_below.head(20)
# Out:
# system_name
# Tennessee School for Blind       39.587500
# Fayette County Public Schools    39.322222
# Haywood County                   37.308911
# Davidson County                  36.704815
# Union County                     35.685606
# Humboldt City Schools            35.671845
# Madison County                   35.139286
# Lake County                      35.034694
# Hancock County                   34.679715
# Memphis-Shelby County Schools    34.502532
# Cannon County                    34.089895
# Campbell County                  33.918687
# Maury County                     33.844613
# Bedford County                   32.963048
# Hardeman County Schools          32.182099
# Wayne County                     32.109936
# Johnson County                   31.952239
# Lauderdale County                31.388580
# Hamilton County                  31.288208
# Warren County                    31.261494
# Name: pct_below, dtype: float64

# %%
subject_count = filtered_assessment['subject'].value_counts()

# %%
subject_count
# Out:
# subject
# ELA                    17131
# Math                   17092
# Science                16746
# Social Studies          9478
# Biology I               5510
# Geometry                5181
# Algebra I               4924
# Algebra II              4391
# English I               4082
# English II              3979
# US History              2990
# Integrated Math II       569
# Integrated Math III      515
# Integrated Math I        435
# Name: count, dtype: int64

# %%
filtered_assessment['actual_subject'] = filtered_assessment['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3098448115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['actual_subject'] = filtered_assessment['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})

# %%
filtered_assessment.head()
# Out:
#    year  system    system_name test    subject grade  \
# 0  2023     950  Wilson County  EOC  Algebra I    10
# 2  2023     950  Wilson County  EOC  Algebra I    10
# 3  2023     950  Wilson County  EOC  Algebra I    10
# 7  2023     950  Wilson County  EOC  Algebra I    10
# 9  2023     950  Wilson County  EOC  Algebra I    10
#
#                     student_group participation_rate  enrolled  tested  ...  \
# 0                    All Students                100        77      77  ...
# 2       Black or African American                100        12      12  ...
# 3  Black/Hispanic/Native American                100        33      33  ...
# 7                          Female                100        35      35  ...
# 9                        Hispanic                100        21      21  ...
#
#    n_below n_approaching n_met_expectations n_exceeded_expectations pct_below  \
# 0       **            **                 **                      **       NaN
# ...

# %%
subject_me = filtered_assessment.groupby('actual_subject')['pct_met_exceeded'].mean().sort_values(ascending=False)

# %%
subject_me
# Out:
# actual_subject
# Sciences       39.701395
# History        38.551553
# English        34.286772
# Mathematics    32.746942
# Name: pct_met_exceeded, dtype: float64

# %%
subject_below = filtered_assessment.groupby('actual_subject')['pct_below'].mean().sort_values(ascending=False)

# %%
subject_below
# Out:
# actual_subject
# Mathematics    33.587810
# History        23.066191
# English        20.289159
# Sciences       18.459329
# Name: pct_below, dtype: float64

# %%
filtered_assessment['pct_approaching'] = filtered_assessment['pct_approaching'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3629956681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_approaching'] = filtered_assessment['pct_approaching'].str.replace('**', '')

# %%
filtered_assessment['pct_approaching'] = filtered_assessment['pct_approaching'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\2189645792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_approaching'] = filtered_assessment['pct_approaching'].str.replace('*', '')

# %%
filtered_assessment.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1657455749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment.replace("", np.nan, inplace=True)

# %%
filtered_assessment[['pct_approaching']] = filtered_assessment[['pct_approaching']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3604014196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment[['pct_approaching']] = filtered_assessment[['pct_approaching']].astype(float)

# %%
filtered_assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93023 entries, 0 to 180233
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       93023 non-null  int64
#  1   system                     93023 non-null  int64
#  2   system_name                93023 non-null  object
#  3   test                       93023 non-null  object
#  4   subject                    93023 non-null  object
#  5   grade                      93023 non-null  object
#  6   student_group              93023 non-null  object
#  7   participation_rate         93023 non-null  object
#  8   enrolled                   93023 non-null  int64
#  9   tested                     93023 non-null  int64
#  10  valid_tests                93023 non-null  int64
#  11  n_below                    93023 non-null  object
#  12  n_approaching              93023 non-null  object
# ...

# %%
filtered_assessment['pct_below_approaching'] = filtered_assessment['pct_below'] + filtered_assessment['pct_approaching']
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\764821887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_assessment['pct_below_approaching'] = filtered_assessment['pct_below'] + filtered_assessment['pct_approaching']

# %%
sg_below_approaching = filtered_assessment.groupby('student_group')['pct_below_approaching'].mean().sort_values(ascending=False)

# %%
sg_below_approaching
# Out:
# student_group
# Migrant                                       85.950000
# English Learners                              77.575342
# Students with Disabilities                    75.818662
# Homeless                                      72.363306
# English Learners with Transitional 1-4        71.079852
# Economically Disadvantaged                    70.673707
# Students with Active Duty Military Parents    69.420290
# Foster                                        69.420290
# Super Subgroup                                69.388165
# Black or African American                     67.538997
# Black/Hispanic/Native American                67.227735
# Hispanic                                      65.111473
# Male                                          60.248323
# All Students                                  59.514736
# Non-English Learners/Transitional 1-4         58.823143
# Female                                        58.795386
# ...

# %%
system_below_approaching = filtered_assessment.groupby('system_name')['pct_below_approaching'].mean().sort_values(ascending=False)

# %%
system_below_approaching.head(20)
# Out:
# system_name
# Humboldt City Schools            81.774757
# Haywood County                   77.640594
# Fayette County Public Schools    77.289167
# Morgan County                    75.705455
# Lake County                      75.479592
# Cannon County                    74.943554
# Houston County                   74.692628
# Hardeman County Schools          74.377160
# Hancock County                   74.041993
# Union County                     73.243182
# Campbell County                  72.607828
# Perry County                     72.587429
# Wayne County                     72.155769
# Lauderdale County                71.748457
# Monroe County                    71.184123
# Warren County                    71.092146
# Johnson County                   70.165885
# Bedford County                   70.011619
# Maury County                     69.695118
# Claiborne County                 69.397506
# Name: pct_below_approaching, dtype: float64

# %%
subject_below_approaching = filtered_assessment.groupby('actual_subject')['pct_below_approaching'].mean().sort_values(ascending=False)

# %%
subject_below_approaching
# Out:
# actual_subject
# Mathematics    63.367840
# English        62.425123
# History        58.294590
# Sciences       57.450664
# Name: pct_below_approaching, dtype: float64

# %%
sg_all = filtered_assessment[filtered_assessment['student_group'] == 'All Students']

# %%
sg_all
# Out:
#         year  system                  system_name     test         subject  \
# 0       2023     950                Wilson County      EOC       Algebra I
# 20      2023     950                Wilson County      EOC       Algebra I
# 43      2023     950                Wilson County      EOC       Algebra I
# 62      2023     950                Wilson County      EOC       Algebra I
# 86      2023     950                Wilson County      EOC       Algebra I
# ...      ...     ...                          ...      ...             ...
# 180125  2023     985  Achievement School District  TNReady  Social Studies
# 180168  2023     985  Achievement School District      EOC      US History
# 180182  2023     985  Achievement School District      EOC      US History
# 180197  2023     985  Achievement School District      EOC      US History
# 180218  2023     985  Achievement School District      EOC      US History
#
# ...

# %%
top_system_me = sg_all.groupby('system_name')['pct_met_exceeded'].mean().sort_values(ascending=False)

# %%
top_system_me.head(10)
# Out:
# system_name
# Lakeland             63.716216
# Franklin SSD         63.421875
# Maryville            61.870588
# Arlington            60.020833
# Germantown           58.822000
# Williamson County    56.944706
# Newport              55.552000
# Lexington            54.748000
# Gibson Co Sp Dist    54.624444
# Johnson City         53.380702
# Name: pct_met_exceeded, dtype: float64

# %%
filtered_assessment.to_csv('filtered_assessment.csv', index=False)

# %%
tvaas = pd.read_csv('../data/2023_tvaas_district_composite (2).csv', encoding='latin-1')

# %%
tvaas.head()
# Out:
#    District Number    District Name  Overall Composite  Literacy Composite  \
# 0               10  Anderson County                  3                   2
# 1              100    Carter County                  5                   3
# 2              101     Elizabethton                  3                   2
# 3               11          Clinton                  5                   5
# 4              110  Cheatham County                  5                   5
#
#    Numeracy Composite  Literacy and Numeracy Composite  Science Composite  \
# 0                   5                                3                1.0
# 1                   5                                5                4.0
# 2                   5                                4                1.0
# 3                   5                                5                3.0
# 4                   5                                5                5.0
#
#    Social Studies Composite
# 0                       3.0
# ...

# %%
tvaas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   District Number                  146 non-null    int64
#  1   District Name                    146 non-null    object
#  2   Overall Composite                146 non-null    int64
#  3   Literacy Composite               146 non-null    int64
#  4   Numeracy Composite               146 non-null    int64
#  5   Literacy and Numeracy Composite  146 non-null    int64
#  6   Science Composite                145 non-null    float64
#  7   Social Studies Composite         143 non-null    float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.3+ KB

# %%
tvaas_overall = tvaas.groupby(['District Name', 'Overall Composite']).sum().reset_index()

# %%
sorted_tvaas_overall = tvaas_overall.sort_values(by='Overall Composite', ascending=False)

# %%
sorted_tvaas_overall.head()
# Out:
#                                   District Name  Overall Composite  \
# 145                               Wilson County                  5
# 36                                  Dyer County                  5
# 41                                 Fayetteville                  5
# 127  Tennessee Public Charter School Commission                  5
# 45                                   Germantown                  5
#
#      District Number  Literacy Composite  Numeracy Composite  \
# 145              950                   3                   5
# 36               230                   3                   5
# 41               521                   3                   5
# 127              987                   5                   5
# 45               796                   5                   3
#
#      Literacy and Numeracy Composite  Science Composite  \
# 145                                5                5.0
# 36                                 5                5.0
# ...

# %%
sorted_tvaas_overall.nsmallest(10, 'Overall Composite')
# Out:
#                      District Name  Overall Composite  District Number  \
# 29               Cumberland County                  1              180
# 121                   Smith County                  1              800
# 122                  South Carroll                  1               95
# 123                 Stewart County                  1              810
# 56                   Hardin County                  1              360
# 48                 Grainger County                  1              290
# 47                    Giles County                  1              280
# 40   Fayette County Public Schools                  1              240
# 33                  Decatur County                  1              200
# 130                  Tipton County                  1              840
#
#      Literacy Composite  Numeracy Composite  Literacy and Numeracy Composite  \
# 29                    3                   5                                4
# ...

# %%
tvaas.to_csv('tvaas.csv', index=False)

# %%
rg_df = pd.read_csv('../data/ready_graduate_district_suppressed_22-23.csv', encoding='latin-1')

# %%
rg_df.head()
# Out:
#    system      system_name                     student_group  n_count  \
# 0      10  Anderson County                      All Students      533
# 1      10  Anderson County  American Indian or Alaska Native        1
# 2      10  Anderson County                             Asian        7
# 3      10  Anderson County         Black or African American       15
# 4      10  Anderson County    Black/Hispanic/Native American       33
#
#   n_ready_grad pct_ready_grad
# 0          229             43
# 1            *              *
# 2            *              *
# 3            2           13.3
# 4           10           30.3

# %%
rg_df.dtypes
# Out:
# system             int64
# system_name       object
# student_group     object
# n_count            int64
# n_ready_grad      object
# pct_ready_grad    object
# dtype: object

# %%
rg_df['n_ready_grad'] = rg_df['n_ready_grad'].str.replace('*', 'NaN')

# %%
rg_df['pct_ready_grad'] = rg_df['pct_ready_grad'].str.replace('*', 'NaN')

# %%
rg_df.head()
# Out:
#    system      system_name                     student_group  n_count  \
# 0      10  Anderson County                      All Students      533
# 1      10  Anderson County  American Indian or Alaska Native        1
# 2      10  Anderson County                             Asian        7
# 3      10  Anderson County         Black or African American       15
# 4      10  Anderson County    Black/Hispanic/Native American       33
#
#   n_ready_grad pct_ready_grad
# 0          229             43
# 1          NaN            NaN
# 2          NaN            NaN
# 3            2           13.3
# 4           10           30.3

# %%
rg_df['n_ready_grad'] = pd.to_numeric(rg_df['n_ready_grad'], errors='coerce')

# %%
rg_df['pct_ready_grad'] = pd.to_numeric(rg_df['pct_ready_grad'], errors='coerce')

# %%
rg_df.dtypes
# Out:
# system              int64
# system_name        object
# student_group      object
# n_count             int64
# n_ready_grad      float64
# pct_ready_grad    float64
# dtype: object

# %%
rg_df.head()
# Out:
#    system      system_name                     student_group  n_count  \
# 0      10  Anderson County                      All Students      533
# 1      10  Anderson County  American Indian or Alaska Native        1
# 2      10  Anderson County                             Asian        7
# 3      10  Anderson County         Black or African American       15
# 4      10  Anderson County    Black/Hispanic/Native American       33
#
#    n_ready_grad  pct_ready_grad
# 0         229.0            43.0
# 1           NaN             NaN
# 2           NaN             NaN
# 3           2.0            13.3
# 4          10.0            30.3

# %%
rg_df.to_csv('rg_df.csv', index=False)

# %%
filtered_assessment.head()
# Out:
#    year  system    system_name test    subject grade  \
# 0  2023     950  Wilson County  EOC  Algebra I    10
# 2  2023     950  Wilson County  EOC  Algebra I    10
# 3  2023     950  Wilson County  EOC  Algebra I    10
# 7  2023     950  Wilson County  EOC  Algebra I    10
# 9  2023     950  Wilson County  EOC  Algebra I    10
#
#                     student_group participation_rate  enrolled  tested  ...  \
# 0                    All Students                100        77      77  ...
# 2       Black or African American                100        12      12  ...
# 3  Black/Hispanic/Native American                100        33      33  ...
# 7                          Female                100        35      35  ...
# 9                        Hispanic                100        21      21  ...
#
#    n_approaching n_met_expectations n_exceeded_expectations pct_below  \
# 0             **                 **                      **       NaN
# ...

# %%
filtered_district.rename(columns={'district_name':'system_name'}, inplace=True)

# %%
filtered_district.head()
# Out:
#   school_year  district_id         system_name   total african_american_pct  \
# 0     2022-23            0  State of Tennessee  973983                   24
# 1     2022-23           10     Anderson County    6019                    4
# 2     2022-23           11             Clinton     933                    6
# 3     2022-23           12           Oak Ridge    4730                   16
# 4     2022-23           20      Bedford County    8827                   12
#
#       asian_pct black_hispanic_native_american_pct  \
# 0             3                                 38
# 1  Less than 1%                                  9
# 2             2                                 11
# 3             3                                 27
# 4             1                                 42
#
#    economically_disadvantaged_pct female_pct    foster_pct  ...  homeless_pct  \
# 0                              30         49  Less than 1%  ...             2
# ...

# %%
merged_d_a = pd.merge(filtered_assessment, filtered_district[['system_name', 'zip code']], on='system_name', how='left')

# %%
merged_d_a.head()
# Out:
#    year  system    system_name test    subject grade  \
# 0  2023     950  Wilson County  EOC  Algebra I    10
# 1  2023     950  Wilson County  EOC  Algebra I    10
# 2  2023     950  Wilson County  EOC  Algebra I    10
# 3  2023     950  Wilson County  EOC  Algebra I    10
# 4  2023     950  Wilson County  EOC  Algebra I    10
#
#                     student_group participation_rate  enrolled  tested  ...  \
# 0                    All Students                100        77      77  ...
# 1       Black or African American                100        12      12  ...
# 2  Black/Hispanic/Native American                100        33      33  ...
# 3                          Female                100        35      35  ...
# 4                        Hispanic                100        21      21  ...
#
#    n_met_expectations n_exceeded_expectations pct_below pct_approaching  \
# 0                  **                      **       NaN             NaN
# ...

# %%
merged_d_a.to_csv('merged_d_a.csv', index=False)

# %%
district_assessment22 = pd.read_csv('../data/district_assessment_file_suppressed_upd32323.csv', encoding='latin-1')

# %%
district_assessment22.head()
# Out:
#    year  system      system_name test    subject grade  \
# 0  2022      10  Anderson County  EOC  Algebra I    10
# 1  2022      10  Anderson County  EOC  Algebra I    10
# 2  2022      10  Anderson County  EOC  Algebra I    10
# 3  2022      10  Anderson County  EOC  Algebra I    10
# 4  2022      10  Anderson County  EOC  Algebra I    10
#
#                       student_group participation_rate  enrolled  tested  \
# 0                      All Students                 99        79      78
# 1  American Indian or Alaska Native                  *         1       1
# 2         Black or African American                  *         2       2
# 3    Black/Hispanic/Native American                  *        10      10
# 4        Economically Disadvantaged                 97        34      33
#
#    valid_tests n_below n_approaching n_met_expectations  \
# 0           77      **            **                 **
# 1            1       *             *                  *
# ...

# %%
filtered_district_assessment22 = district_assessment22[district_assessment22['participation_rate'] != '*']

# %%
filtered_district_assessment22['pct_met_exceeded'] = filtered_district_assessment22['pct_met_exceeded'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\380714361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_met_exceeded'] = filtered_district_assessment22['pct_met_exceeded'].str.replace('**', '')

# %%
filtered_district_assessment22['pct_met_exceeded'] = filtered_district_assessment22['pct_met_exceeded'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1766123874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_met_exceeded'] = filtered_district_assessment22['pct_met_exceeded'].str.replace('*', '')

# %%
filtered_district_assessment22.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\349819824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment22[['pct_met_exceeded']] = filtered_district_assessment22[['pct_met_exceeded']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\412422156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22[['pct_met_exceeded']] = filtered_district_assessment22[['pct_met_exceeded']].astype(float)

# %%
filtered_district_assessment22['actual_subject'] = filtered_district_assessment22['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3800773815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['actual_subject'] = filtered_district_assessment22['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})

# %%
filtered_district_assessment22['pct_below'] = filtered_district_assessment22['pct_below'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1499601246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_below'] = filtered_district_assessment22['pct_below'].str.replace('**', '')

# %%
filtered_district_assessment22['pct_below'] = filtered_district_assessment22['pct_below'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3910342698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_below'] = filtered_district_assessment22['pct_below'].str.replace('*', '')

# %%
filtered_district_assessment22.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\349819824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment22[['pct_below']] = filtered_district_assessment22[['pct_below']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\2828190745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22[['pct_below']] = filtered_district_assessment22[['pct_below']].astype(float)

# %%
filtered_district_assessment22['pct_approaching'] = filtered_district_assessment22['pct_approaching'].str.replace('**', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3372559445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_approaching'] = filtered_district_assessment22['pct_approaching'].str.replace('**', '')

# %%
filtered_district_assessment22['pct_approaching'] = filtered_district_assessment22['pct_approaching'].str.replace('*', '')
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1488290404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_approaching'] = filtered_district_assessment22['pct_approaching'].str.replace('*', '')

# %%
filtered_district_assessment22.replace("", np.nan, inplace=True)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\349819824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment22[['pct_approaching']] = filtered_district_assessment22[['pct_approaching']].astype(float)
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\1293889314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22[['pct_approaching']] = filtered_district_assessment22[['pct_approaching']].astype(float)

# %%
filtered_district_assessment22['pct_below_approaching'] = filtered_district_assessment22['pct_below'] + filtered_district_assessment22['pct_approaching']
# Out:
# C:\Users\Owne\AppData\Local\Temp\ipykernel_23340\3506895307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_district_assessment22['pct_below_approaching'] = filtered_district_assessment22['pct_below'] + filtered_district_assessment22['pct_approaching']

# %%
filtered_district_assessment22.dtypes
# Out:
# year                           int64
# system                         int64
# system_name                   object
# test                          object
# subject                       object
# grade                         object
# student_group                 object
# participation_rate            object
# enrolled                       int64
# tested                         int64
# valid_tests                    int64
# n_below                       object
# n_approaching                 object
# n_met_expectations            object
# n_exceeded_expectations       object
# pct_below                    float64
# pct_approaching              float64
# pct_met_expectations          object
# pct_exceeded_expectations     object
# pct_met_exceeded             float64
# actual_subject                object
# pct_below_approaching        float64
# dtype: object

# %%
subject_count22 = filtered_district_assessment22['subject'].value_counts()

# %%
subject_count22
# Out:
# subject
# ELA                    16548
# Math                   16514
# Science                16289
# Social Studies          9314
# Biology I               5489
# Algebra I               4826
# Geometry                4759
# Algebra II              4415
# English I               4021
# English II              3973
# US History              3073
# Integrated Math II       679
# Integrated Math I        583
# Integrated Math III      538
# Name: count, dtype: int64

# %%
filtered_district_assessment22.to_csv('filtered_district_assessment22.csv', index=False)

# %%
district_assessment21 = pd.read_csv('../data/district_assessment_file_suppressed_upd422.csv', encoding='latin-1')

# %%
filtered_district_assessment21 = district_assessment21[district_assessment21['participation_rate'] != '*']

# %%
filtered_district_assessment21 = district_assessment21[district_assessment21['participation_rate'] != '**']

# %%
filtered_district_assessment21.head()
# Out:
#    year  system      system_name test    subject grade  \
# 0  2021      10  Anderson County  EOC  Algebra I    10
# 1  2021      10  Anderson County  EOC  Algebra I    10
# 2  2021      10  Anderson County  EOC  Algebra I    10
# 3  2021      10  Anderson County  EOC  Algebra I    10
# 4  2021      10  Anderson County  EOC  Algebra I    10
#
#                          subgroup participation_rate  enrolled  tested  \
# 0                    All Students                 94        89      84
# 1       Black or African American                  *         4       4
# 2  Black/Hispanic/Native American                  *         9       8
# 3      Economically Disadvantaged                 94        36      34
# 4                English Learners                  *         3       2
#
#    valid_tests n_below n_approaching n_on_track n_mastered pct_below  \
# 0           82      **            **         **         **        **
# ...

# %%
filtered_district_assessment21['pct_on_mastered'] = filtered_district_assessment21['pct_on_mastered'].str.replace('**', '')

# %%
filtered_district_assessment21['pct_on_mastered'] = filtered_district_assessment21['pct_on_mastered'].str.replace('*', '')

# %%
filtered_district_assessment21.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment21[['pct_on_mastered']] = filtered_district_assessment21[['pct_on_mastered']].astype(float)

# %%
filtered_district_assessment21['actual_subject'] = filtered_district_assessment21['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})

# %%
filtered_district_assessment21['pct_below'] = filtered_district_assessment21['pct_below'].str.replace('**', '')

# %%
filtered_district_assessment21['pct_below'] = filtered_district_assessment21['pct_below'].str.replace('*', '')

# %%
filtered_district_assessment21.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment21[['pct_below']] = filtered_district_assessment21[['pct_below']].astype(float)

# %%
filtered_district_assessment21['pct_approaching'] = filtered_district_assessment21['pct_approaching'].str.replace('**', '')

# %%
filtered_district_assessment21['pct_approaching'] = filtered_district_assessment21['pct_approaching'].str.replace('*', '')

# %%
filtered_district_assessment21.replace("", np.nan, inplace=True)

# %%
filtered_district_assessment21[['pct_approaching']] = filtered_district_assessment21[['pct_approaching']].astype(float)

# %%
filtered_district_assessment21['pct_below_approaching'] = filtered_district_assessment21['pct_below'] + filtered_district_assessment21['pct_approaching']

# %%
filtered_district_assessment21.dtypes
# Out:
# year                       int64
# system                     int64
# system_name               object
# test                      object
# subject                   object
# grade                     object
# subgroup                  object
# participation_rate        object
# enrolled                   int64
# tested                     int64
# valid_tests                int64
# n_below                   object
# n_approaching             object
# n_on_track                object
# n_mastered                object
# pct_below                float64
# pct_approaching          float64
# pct_on_track              object
# pct_mastered              object
# pct_on_mastered          float64
# actual_subject            object
# pct_below_approaching    float64
# dtype: object

# %%
filtered_district_assessment21.to_csv('filtered_district_assessment21.csv', index=False)

# %%
district_assessment19 = pd.read_csv('../data/district_assessment_file_suppressed19.csv', encoding='latin-1')

# %%
district_assessment19.head()
# Out:
#    year  system      system_name test    subject grade  \
# 0  2019      10  Anderson County  EOC  Algebra I    10
# 1  2019      10  Anderson County  EOC  Algebra I    10
# 2  2019      10  Anderson County  EOC  Algebra I    10
# 3  2019      10  Anderson County  EOC  Algebra I    10
# 4  2019      10  Anderson County  EOC  Algebra I    10
#
#                            subgroup  enrolled  tested  valid_tests n_below  \
# 0                      All Students       100     100          100      **
# 1  American Indian or Alaska Native         2       2            2       *
# 2         Black or African American         1       1            1       *
# 3    Black/Hispanic/Native American         4       4            4       *
# 4        Economically Disadvantaged        29      29           29      **
#
#   n_approaching n_on_track n_mastered pct_below pct_approaching pct_on_track  \
# 0            **         **         **        **              **           **
# ...

# %%
district_assessment19['pct_on_mastered'] = district_assessment19['pct_on_mastered'].str.replace('**', '')

# %%
district_assessment19['pct_on_mastered'] = district_assessment19['pct_on_mastered'].str.replace('*', '')

# %%
district_assessment19.replace("", np.nan, inplace=True)

# %%
district_assessment19[['pct_on_mastered']] = district_assessment19[['pct_on_mastered']].astype(float)

# %%
district_assessment19['pct_below'] = district_assessment19['pct_below'].str.replace('**', '')

# %%
district_assessment19['pct_below'] = district_assessment19['pct_below'].str.replace('*', '')

# %%
district_assessment19.replace("", np.nan, inplace=True)

# %%
district_assessment19[['pct_below']] = district_assessment19[['pct_below']].astype(float)

# %%
district_assessment19['pct_approaching'] = district_assessment19['pct_approaching'].str.replace('**', '')

# %%
district_assessment19['pct_approaching'] = district_assessment19['pct_approaching'].str.replace('*', '')

# %%
district_assessment19.replace("", np.nan, inplace=True)

# %%
district_assessment19[['pct_approaching']] = district_assessment19[['pct_approaching']].astype(float)

# %%
district_assessment19['pct_below_approaching'] = district_assessment19['pct_below'] + district_assessment19['pct_approaching']

# %%
district_assessment19['actual_subject'] = district_assessment19['subject'].replace({'ELA':'English', 'Math':'Mathematics', 'Science':'Sciences', 'Social Studies':'History', 'Biology I':'Sciences', 'Geometry':'Mathematics', 'Algebra I':'Mathematics', 'Algebra II':'Mathematics', 'English I':'English', 'English II':'English', 'US History':'History', 'Integrated Math II':'Mathematics', 'Integrated Math III':'Mathematics', 'Integrated Math I':'Mathematics'})

# %%
district_assessment19.dtypes
# Out:
# year                       int64
# system                     int64
# system_name               object
# test                      object
# subject                   object
# grade                     object
# subgroup                  object
# enrolled                   int64
# tested                     int64
# valid_tests                int64
# n_below                   object
# n_approaching             object
# n_on_track                object
# n_mastered                object
# pct_below                float64
# pct_approaching          float64
# pct_on_track              object
# pct_mastered              object
# pct_on_mastered          float64
# pct_below_approaching    float64
# actual_subject            object
# dtype: object

# %%
district_assessment19.to_csv('district_assessment19.csv', index=False)

# %%
assess19 = pd.read_excel('../data/2019_Assessment.xlsx')

# %%
assess19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118876 entries, 0 to 118875
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   118876 non-null  int64
#  1   system_name            118876 non-null  object
#  2   student_group          118876 non-null  object
#  3   actual_subject         118876 non-null  object
#  4   pct_met_exceeded       64416 non-null   float64
#  5   pct_below_approaching  47542 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.4+ MB

# %%
assess21 = pd.read_excel('../data/2021_Assessment.xlsx')

# %%
assess21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165487 entries, 0 to 165486
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year                   165487 non-null  int64
#  1   system_name            165487 non-null  object
#  2   student_group          165487 non-null  object
#  3   actual_subject         165487 non-null  object
#  4   pct_met_exceeded       82665 non-null   float64
#  5   pct_below_approaching  51635 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.6+ MB

# %%
assess22 = pd.read_excel('../data/2022_Assessment.xlsx')

# %%
assess22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91021 entries, 0 to 91020
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   91021 non-null  int64
#  1   system_name            91021 non-null  object
#  2   student_group          91021 non-null  object
#  3   actual_subject         91021 non-null  object
#  4   pct_met_exceeded       86847 non-null  float64
#  5   pct_below_approaching  62035 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.2+ MB

# %%
expenditures = pd.read_excel('../data/EducationDataPortal_06.18.2024_School Districts (2).xlsx')

# %%
expenditures.head()
# Out:
#                   year    leaid                     lea_name state_location  \
# 0  mixed - most recent  4700147  Achievement School District             TN
# 1  mixed - most recent  4700030                        Alamo             TN
# 2  mixed - most recent  4700060                        Alcoa             TN
# 3  mixed - most recent  4700144       Alvin C York Institute             TN
# 4  mixed - most recent  4700090              Anderson County             TN
#
#   city_location                         agency_type  enrollment  \
# 0     Nashville  Specialized public school district        5966
# 1         Alamo       Regular local school district         578
# 2         Alcoa       Regular local school district        2211
# 3     Jamestown  Specialized public school district         492
# 4       Clinton       Regular local school district        6317
#
#               exp_total exp_current_elsec_total exp_current_state_local_funds  \
# ...

# %%
expenditures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           148 non-null    object
#  1   leaid                          148 non-null    int64
#  2   lea_name                       148 non-null    object
#  3   state_location                 148 non-null    object
#  4   city_location                  148 non-null    object
#  5   agency_type                    148 non-null    object
#  6   enrollment                     148 non-null    int64
#  7   exp_total                      146 non-null    object
#  8   exp_current_elsec_total        146 non-null    object
#  9   exp_current_state_local_funds  146 non-null    object
#  10  exp_current_federal_funds      146 non-null    object
#  11  exp_current_resa               10 non-null     object
# ...

# %%
expenditures.drop(columns='exp_current_resa')
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
expenditures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           148 non-null    object
#  1   leaid                          148 non-null    int64
#  2   lea_name                       148 non-null    object
#  3   state_location                 148 non-null    object
#  4   city_location                  148 non-null    object
#  5   agency_type                    148 non-null    object
#  6   enrollment                     148 non-null    int64
#  7   exp_total                      146 non-null    object
#  8   exp_current_elsec_total        146 non-null    object
#  9   exp_current_state_local_funds  146 non-null    object
#  10  exp_current_federal_funds      146 non-null    object
#  11  exp_current_resa               10 non-null     object
# ...

# %%
exp_a = expenditures.drop(columns='exp_current_resa')

# %%
exp_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           148 non-null    object
#  1   leaid                          148 non-null    int64
#  2   lea_name                       148 non-null    object
#  3   state_location                 148 non-null    object
#  4   city_location                  148 non-null    object
#  5   agency_type                    148 non-null    object
#  6   enrollment                     148 non-null    int64
#  7   exp_total                      146 non-null    object
#  8   exp_current_elsec_total        146 non-null    object
#  9   exp_current_state_local_funds  146 non-null    object
#  10  exp_current_federal_funds      146 non-null    object
#  11  exp_current_instruction_total  146 non-null    object
# ...

# %% [markdown]
# exp_a['exp_total'] = exp_a['exp_total'].str.replace('Missing/not reported', '')

# %% [markdown]
# exp_a.replace("", np.nan, inplace=True)

# %% [markdown]
# exp_a[['exp_total']] = exp_a[['exp_total']].astype(float)

# %%
exp_a = exp_a.replace('Missing/not reported', '')

# %%
exp_a.replace("", np.nan, inplace=True)

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a.isna()
# Out:
#       year  leaid  lea_name  state_location  city_location  agency_type  \
# 0    False  False     False           False          False        False
# 1    False  False     False           False          False        False
# 2    False  False     False           False          False        False
# 3    False  False     False           False          False        False
# 4    False  False     False           False          False        False
# ..     ...    ...       ...             ...            ...          ...
# 143  False  False     False           False          False        False
# 144  False  False     False           False          False        False
# 145  False  False     False           False          False        False
# 146  False  False     False           False          False        False
# 147  False  False     False           False          False        False
#
#      enrollment  exp_total  exp_current_elsec_total  \
# ...

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a[['exp_total']] = exp_a[['exp_total']].astype(float)

# %%
exp_a[['exp_current_elsec_total']] = exp_a[['exp_current_elsec_total']].astype(float)

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           148 non-null    object
#  1   leaid                          148 non-null    int64
#  2   lea_name                       148 non-null    object
#  3   state_location                 148 non-null    object
#  4   city_location                  148 non-null    object
#  5   agency_type                    148 non-null    object
#  6   enrollment                     148 non-null    int64
#  7   exp_total                      142 non-null    float64
#  8   exp_current_elsec_total        142 non-null    float64
#  9   exp_current_state_local_funds  142 non-null    float64
#  10  exp_current_federal_funds      142 non-null    float64
#  11  exp_current_instruction_total  142 non-null    float64
# ...

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a['city/state'] = exp_a['city_location'] + ', ' + exp_a['state_location']

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a['exp_per_student'] = exp_a['exp_current_elsec_total'] / exp_a['enrollment']

# %%
exp_a
# Out:
#                     year    leaid                            lea_name  \
# 0    mixed - most recent  4700147         Achievement School District
# 1    mixed - most recent  4700030                               Alamo
# 2    mixed - most recent  4700060                               Alcoa
# 3    mixed - most recent  4700144              Alvin C York Institute
# 4    mixed - most recent  4700090                     Anderson County
# ..                   ...      ...                                 ...
# 143  mixed - most recent  4704490                West Carroll Sp Dist
# 144  mixed - most recent  4700143  West Tennessee School for the Deaf
# 145  mixed - most recent  4704500                        White County
# 146  mixed - most recent  4704530                   Williamson County
# 147  mixed - most recent  4704550                       Wilson County
#
#     state_location city_location                         agency_type  \
# ...

# %%
exp_a.nlargest(20,'exp_per_student')
# Out:
#                     year    leaid                       lea_name  \
# 18   mixed - most recent  4700480                 Carroll County
# 0    mixed - most recent  4700147    Achievement School District
# 45   mixed - most recent  4701260                   Franklin SSD
# 31   mixed - most recent  4703180                Davidson County
# 114  mixed - most recent  4703540                   Richard City
# 104  mixed - most recent  4703240                      Oak Ridge
# 76   mixed - most recent  4702310              Lauderdale County
# 95   mixed - most recent  4700148  Memphis-Shelby County Schools
# 65   mixed - most recent  4701950          Humboldt City Schools
# 42   mixed - most recent  4701200                   Fayetteville
# 109  mixed - most recent  4703390                   Perry County
# 11   mixed - most recent  4700270                 Bledsoe County
# 100  mixed - most recent  4703060                   Moore County
# ...

# %%
exp_a.to_excel('exp_a.xlsx', index=False)

# %%
school_scores = pd.read_csv('../data/school_assessment_file_suppressed_2023.csv', encoding='latin-1')

# %%
school_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715343 entries, 0 to 715342
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   year                       715343 non-null  int64
#  1   system                     715343 non-null  int64
#  2   system_name                715343 non-null  object
#  3   school                     715343 non-null  int64
#  4   school_name                715343 non-null  object
#  5   test                       715343 non-null  object
#  6   subject                    715343 non-null  object
#  7   grade                      715343 non-null  object
#  8   student_group              715343 non-null  object
#  9   participation_rate         715343 non-null  object
#  10  enrolled                   715343 non-null  int64
#  11  tested                     715343 non-null  int64
#  12  valid_tests                715343 non-null  int64
# ...

# %%
school_scores.head()
# Out:
#    year  system      system_name  school                  school_name test  \
# 0  2023      10  Anderson County       2  Anderson County High School  EOC
# 1  2023      10  Anderson County       2  Anderson County High School  EOC
# 2  2023      10  Anderson County       2  Anderson County High School  EOC
# 3  2023      10  Anderson County       2  Anderson County High School  EOC
# 4  2023      10  Anderson County       2  Anderson County High School  EOC
#
#      subject grade               student_group participation_rate  ...  \
# 0  Algebra I    10                All Students                 96  ...
# 1  Algebra I    10  Economically Disadvantaged                100  ...
# 2  Algebra I    10                      Female                100  ...
# 3  Algebra I    10                    Homeless                  *  ...
# 4  Algebra I    10                        Male                 93  ...
#
#    valid_tests  n_below  n_approaching n_met_expectations  \
# ...

# %%
MNPS = school_scores[school_scores['system_name'] == 'Davidson County']

# %%
MNPS
# Out:
#         year  system      system_name  school              school_name  \
# 90832   2023     190  Davidson County       1  A. Z. Kelley Elementary
# 90833   2023     190  Davidson County       1  A. Z. Kelley Elementary
# 90834   2023     190  Davidson County       1  A. Z. Kelley Elementary
# 90835   2023     190  Davidson County       1  A. Z. Kelley Elementary
# 90836   2023     190  Davidson County       1  A. Z. Kelley Elementary
# ...      ...     ...              ...     ...                      ...
# 154104  2023     190  Davidson County    8110       KA @ The Crossings
# 154105  2023     190  Davidson County    8110       KA @ The Crossings
# 154106  2023     190  Davidson County    8110       KA @ The Crossings
# 154107  2023     190  Davidson County    8110       KA @ The Crossings
# 154108  2023     190  Davidson County    8110       KA @ The Crossings
#
#                                    test         subject       grade  \
# ...

# %%
stratford = MNPS[MNPS['school_name'].str.contains('Stratford', case=False)]

# %%
mlk = MNPS[MNPS['school_name'].str.contains('Martin Luther', case=False)]

# %%
mnps_hs = MNPS[MNPS['school_name'].str.contains(r'\bhigh\b', case=False)]

# %%
mnps_hs = pd.concat([mnps_hs, stratford], ignore_index=True)

# %%
mnps_hs = pd.concat([mnps_hs, mlk], ignore_index=True)

# %%
mnps_hs['school_name'].unique()
# Out:
# array(['Antioch High School', 'Nashville Big Picture High School',
#        'Cane Ridge High School', 'East Nashville Magnet High School',
#        'Glencliff High School', 'Hillsboro High', 'Hillwood High',
#        'Hume - Fogg High', 'Hunters Lane High', 'John Overton High',
#        'Early College High School', 'Maplewood High', 'McGavock High',
#        'Pearl-Cohn High', 'Whites Creek High',
#        'KIPP Nashville Collegiate High School', 'STEM Prep High School',
#        'RePublic High School', 'Stratford STEM Magnet School',
#        'Martin Luther King Jr School'], dtype=object)

# %%
address_mapping = {
    'Antioch High School': '1900 Hobson Pike, Antioch, TN 37013',
    'Nashville Big Picture High School': '160 Rural Ave, Nashville, TN 37209',
    'Cane Ridge High School': '12848 Old Hickory Blvd, Antioch, TN 37013',
    'East Nashville Magnet High School': '110 Gallatin Ave, Nashville, TN 37206',
    'Glencliff High School': '160 Antioch Pike, Nashville, TN 37211',
    'Hillsboro High': '3812 Hillsboro Pike, Nashville, TN 37215',
    'Hillwood High': '400 Davidson Rd, Nashville, TN 37205',
    'Hume - Fogg High': '700 Broadway, Nashville, TN 37203',
    'Hunters Lane High': '1150 Hunters Ln, Nashville, TN 37207',
    'John Overton High': '4820 Franklin Pike, Nashville, TN 37220',
    'Early College High School': '120 White Bridge Pike, Nashville, TN 37209',
    'Maplewood High': '401 Walton Ln, Nashville, TN 37216',
    'McGavock High': '3150 Mcgavock Pike, Nashville, TN 37214',
    'Pearl-Cohn High': '904 26th Ave N, Nashville, TN 37208',
    'Whites Creek High': '7277 Old Hickory Blvd, Whites Creek, TN 37189',
    'KIPP Nashville Collegiate High School': '123 Douglas Ave, Nashville, TN 37207',
    'STEM Prep High School': '1252 Foster Avenue, Nashville, TN 37210',
    'RePublic High School': '3307 Brick Church Pike, Nashville, TN 37207',
    'Stratford STEM Magnet School': '1800 Stratford Ave, Nashville, TN 37216',
    'Martin Luther King Jr School': '613 17th Ave N, Nashville, TN 37203'
}

# %%
mnps_hs['address'] = mnps_hs['school_name'].map(address_mapping)

# %%
mnps_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10868 entries, 0 to 10867
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       10868 non-null  int64
#  1   system                     10868 non-null  int64
#  2   system_name                10868 non-null  object
#  3   school                     10868 non-null  int64
#  4   school_name                10868 non-null  object
#  5   test                       10868 non-null  object
#  6   subject                    10868 non-null  object
#  7   grade                      10868 non-null  object
#  8   student_group              10868 non-null  object
#  9   participation_rate         10868 non-null  object
#  10  enrolled                   10868 non-null  int64
#  11  tested                     10868 non-null  int64
#  12  valid_tests                10868 non-null  int64
# ...

# %%
mnps_hs['pct_met_exceeded'] = mnps_hs['pct_met_exceeded'].str.replace('**', '')

# %%
mnps_hs['pct_met_exceeded'] = mnps_hs['pct_met_exceeded'].str.replace('*', '')

# %%
mnps_hs.replace("", np.nan, inplace=True)

# %%
mnps_hs[['pct_met_exceeded']] = mnps_hs[['pct_met_exceeded']].astype(float)

# %%
mnps_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10868 entries, 0 to 10867
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       10868 non-null  int64
#  1   system                     10868 non-null  int64
#  2   system_name                10868 non-null  object
#  3   school                     10868 non-null  int64
#  4   school_name                10868 non-null  object
#  5   test                       10868 non-null  object
#  6   subject                    10868 non-null  object
#  7   grade                      10868 non-null  object
#  8   student_group              10868 non-null  object
#  9   participation_rate         10868 non-null  object
#  10  enrolled                   10868 non-null  int64
#  11  tested                     10868 non-null  int64
#  12  valid_tests                10868 non-null  int64
# ...

# %%
mnps_hs.to_csv('mnps_hs.csv', index=False)

# %%
LSE = school_scores[school_scores['school_name'] == 'LEAD Southeast']

# %%
LSE
# Out:
#         year  system      system_name  school     school_name     test  \
# 145578  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145579  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145580  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145581  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145582  2023     190  Davidson County    8013  LEAD Southeast      EOC
# ...      ...     ...              ...     ...             ...      ...
# 146548  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146549  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146550  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146551  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146552  2023     190  Davidson County    8013  LEAD Southeast  TNReady
#
#                subject       grade                          student_group  \
# ...

# %%
LSE_8 = LSE[LSE['grade'] == '8']

# %%
LSE_8
# Out:
#         year  system      system_name  school     school_name     test  \
# 145744  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145745  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145746  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145747  2023     190  Davidson County    8013  LEAD Southeast      EOC
# 145748  2023     190  Davidson County    8013  LEAD Southeast      EOC
# ...      ...     ...              ...     ...             ...      ...
# 146529  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146530  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146531  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146532  2023     190  Davidson County    8013  LEAD Southeast  TNReady
# 146533  2023     190  Davidson County    8013  LEAD Southeast  TNReady
#
#                   subject grade                          student_group  \
# ...

# %%
LSE_8_Math = LSE_8[LSE_8['subject'] == 'Math']

# %%
LSE_8_Math
# Out:
#         year  system      system_name  school     school_name  \
# 146088  2023     190  Davidson County    8013  LEAD Southeast
# 146089  2023     190  Davidson County    8013  LEAD Southeast
# 146090  2023     190  Davidson County    8013  LEAD Southeast
# 146091  2023     190  Davidson County    8013  LEAD Southeast
# 146092  2023     190  Davidson County    8013  LEAD Southeast
# 146093  2023     190  Davidson County    8013  LEAD Southeast
# 146094  2023     190  Davidson County    8013  LEAD Southeast
# 146095  2023     190  Davidson County    8013  LEAD Southeast
# 146096  2023     190  Davidson County    8013  LEAD Southeast
# 146097  2023     190  Davidson County    8013  LEAD Southeast
# 146098  2023     190  Davidson County    8013  LEAD Southeast
# 146099  2023     190  Davidson County    8013  LEAD Southeast
# 146100  2023     190  Davidson County    8013  LEAD Southeast
# 146101  2023     190  Davidson County    8013  LEAD Southeast
# ...

# %%
LSE.to_csv('LSE.csv', index=False)

# %%
df_2023 = filtered_assessment[['year', 'system_name', 'student_group', 'pct_met_exceeded']]

# %%
df_2022 = filtered_district_assessment22[['year', 'system_name', 'student_group', 'pct_met_exceeded']]

# %%
filtered_district_assessment21 = filtered_district_assessment21.rename(columns={'stdent_group':'student_group'})

# %%
filtered_district_assessment21
# Out:
#         year  system                         system_name test     subject  \
# 0       2021      10                     Anderson County  EOC   Algebra I
# 1       2021      10                     Anderson County  EOC   Algebra I
# 2       2021      10                     Anderson County  EOC   Algebra I
# 3       2021      10                     Anderson County  EOC   Algebra I
# 4       2021      10                     Anderson County  EOC   Algebra I
# ...      ...     ...                                 ...  ...         ...
# 165482  2021     986  Tennessee State Board of Education  EOC  US History
# 165483  2021     986  Tennessee State Board of Education  EOC  US History
# 165484  2021     986  Tennessee State Board of Education  EOC  US History
# 165485  2021     986  Tennessee State Board of Education  EOC  US History
# 165486  2021     986  Tennessee State Board of Education  EOC  US History
#
#              grade                               subgroup participation_rate  \
# ...

# %%
filtered_district_assessment21 = filtered_district_assessment21.rename(columns={'pct_on_mastered':'pct_met_exceeded'})

# %%
filtered_district_assessment21
# Out:
#         year  system                         system_name test     subject  \
# 0       2021      10                     Anderson County  EOC   Algebra I
# 1       2021      10                     Anderson County  EOC   Algebra I
# 2       2021      10                     Anderson County  EOC   Algebra I
# 3       2021      10                     Anderson County  EOC   Algebra I
# 4       2021      10                     Anderson County  EOC   Algebra I
# ...      ...     ...                                 ...  ...         ...
# 165482  2021     986  Tennessee State Board of Education  EOC  US History
# 165483  2021     986  Tennessee State Board of Education  EOC  US History
# 165484  2021     986  Tennessee State Board of Education  EOC  US History
# 165485  2021     986  Tennessee State Board of Education  EOC  US History
# 165486  2021     986  Tennessee State Board of Education  EOC  US History
#
#              grade                               subgroup participation_rate  \
# ...

# %%
district_assessment19 = district_assessment19.rename(columns={'stdent_group':'student_group'})

# %%
district_assessment19 = district_assessment19.rename(columns={'pct_on_mastered':'pct_met_exceeded'})

# %%
district_assessment19
# Out:
#         year  system                         system_name test    subject  \
# 0       2019      10                     Anderson County  EOC  Algebra I
# 1       2019      10                     Anderson County  EOC  Algebra I
# 2       2019      10                     Anderson County  EOC  Algebra I
# 3       2019      10                     Anderson County  EOC  Algebra I
# 4       2019      10                     Anderson County  EOC  Algebra I
# ...      ...     ...                                 ...  ...        ...
# 118871  2019     986  Tennessee State Board of Education  EOC   Geometry
# 118872  2019     986  Tennessee State Board of Education  EOC   Geometry
# 118873  2019     986  Tennessee State Board of Education  EOC   Geometry
# 118874  2019     986  Tennessee State Board of Education  EOC   Geometry
# 118875  2019     986  Tennessee State Board of Education  EOC   Geometry
#
#              grade                               subgroup  enrolled  tested  \
# ...

# %%
df_2021 = filtered_district_assessment21[['year', 'system_name', 'subgroup', 'pct_met_exceeded']]

# %%
df_2019 = district_assessment19[['year', 'system_name', 'subgroup', 'pct_met_exceeded']]

# %%
combined_df_1923 = pd.concat([df_2019, df_2021, df_2022, df_2023], ignore_index=True)

# %%
combined_df_1923
# Out:
#         year                  system_name                          subgroup  \
# 0       2019              Anderson County                      All Students
# 1       2019              Anderson County  American Indian or Alaska Native
# 2       2019              Anderson County         Black or African American
# 3       2019              Anderson County    Black/Hispanic/Native American
# 4       2019              Anderson County        Economically Disadvantaged
# ...      ...                          ...                               ...
# 468402  2023  Achievement School District                               NaN
# 468403  2023  Achievement School District                               NaN
# 468404  2023  Achievement School District                               NaN
# 468405  2023  Achievement School District                               NaN
# 468406  2023  Achievement School District                               NaN
#
# ...

# %% [markdown]
# combined_df_1923['student_group'] = combined_df_1923['subgroup'] + combined_df_1923['student_group']

# %%
combined_df_1923 = combined_df_1923[combined_df_1923['student_group'] == 'All Students']

# %%
combined_df_1923
# Out:
#         year                  system_name subgroup  pct_met_exceeded  \
# 284363  2022              Anderson County      NaN               1.3
# 284374  2022              Anderson County      NaN              47.9
# 284384  2022              Anderson County      NaN              23.1
# 284397  2022              Anderson County      NaN              25.0
# 284411  2022              Anderson County      NaN              76.3
# ...      ...                          ...      ...               ...
# 468341  2023  Achievement School District      NaN               9.2
# 468368  2023  Achievement School District      NaN               5.5
# 468378  2023  Achievement School District      NaN               6.3
# 468389  2023  Achievement School District      NaN               7.1
# 468396  2023  Achievement School District      NaN               6.1
#
#        student_group
# 284363  All Students
# 284374  All Students
# 284384  All Students
# 284397  All Students
# 284411  All Students
# ...

# %%
combined_df_1923.to_csv('combined_df_1923.csv', index=False)
